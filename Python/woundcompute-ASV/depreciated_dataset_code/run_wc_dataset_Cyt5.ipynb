# %%
#imports
import os, shutil, time, tkinter
from tkinter.filedialog import askdirectory
from pathlib import Path
from woundcompute import image_analysis as ia

# %%
#from PIL import Image

# %%
#prompt user for the file directory. Will open as a popup window named "tk"
tk_root = tkinter.Tk()
path_input = askdirectory(title='Select Input Folder')  # shows dialog box and return the path
print(path_input)
tk_root.destroy()

tk_root = tkinter.Tk()
path_output = askdirectory(title='Select Output Folder')  # shows dialog box and return the path
print(path_output)
tk_root.destroy()
# Out:
# E:/Cytation 5/ASV/20220919_R3P2/220919_182514_20220919_R3P2_AI/Downsized
# E:/Cytation 5/ASV/20220919_R3P2/220919_182514_20220919_R3P2_AI/Output

# %%
#Copy TIF files into folders grouped by plate position
for file in os.listdir(path_input):
    #Check if position described with only 2 characters
    if file[2] == '_':
        if os.path.exists(path_output + '/' + file[:2] + '/ph1_images'):
            try:
                #image = Image.open(path_input + '/' + file)
                #new_image = image.resize((512, 512))
                #new_image.save(path_output + '/' + file[:2] + '/ph1_images/' + file)
                #image.save(path_output + '/' + file[:2] + '/ph1_images/' + file,
                #           "TIFF",
                #           optimize = True,
                #           quality = 25)
                shutil.copy(path_input+'/'+file, path_output+'/'+file[:2]+'/'+'/ph1_images/'+file)

            except OSError as e:
                # If it fails, inform the user.
                print('Error: %s - %s.' % (e.filename, e.strerror))

        else:
            try:
                os.makedirs(path_output + '/' + file[:2] + '/ph1_images')
                shutil.copy('G:/My Drive/Boston University/Chen Lab/Code/Anish/wc_dataset_ph1.yaml',
                            path_output + '/' + file[:2] + '/wc_dataset_ph1.yaml')

                #image = Image.open(path_input + '/' + file)
                #new_image = image.resize((512, 512))
                #new_image.save(path_output + '/' + file[:2] + '/ph1_images/' + file)
                #image.save(path_output + '/' + file[:2] + '/ph1_images/' + file,
                #           "TIFF",
                #           optimize = True,
                #           quality = 25)
                shutil.copy(path_input+'/'+file, path_output+'/'+file[:2]+'/'+'/ph1_images/'+file)

            except OSError as e:
                # If it fails, inform the user.
                print('Error: %s - %s.' % (e.filename, e.strerror))

    #Otherwise, assume position is described with 3 characters
    else:
        if os.path.exists(path_output + '/' + file[:3] + '/ph1_images'):
            try:
                #image = Image.open(path_input + '/' + file)
                #new_image = image.resize((512, 512))
                #new_image.save(path_output + '/' + file[:3] + '/ph1_images/' + file)
                #image.save(path_output + '/' + file[:3] + '/ph1_images/' + file,
                #           "TIFF",
                #           optimize = True,
                #           quality = 25)
                shutil.copy(path_input+'/'+file, path_output+'/'+file[:3]+'/'+'/ph1_images/'+file)

            except OSError as e:
                # If it fails, inform the user.
                print('Error: %s - %s.' % (e.filename, e.strerror))

        else:
            try:
                os.makedirs(path_output + '/' + file[:3] + '/ph1_images')
                shutil.copy('G:/My Drive/Boston University/Chen Lab/Code/Anish/wc_dataset_ph1.yaml',
                            path_output + '/' + file[:3] + '/wc_dataset_ph1.yaml')
                #image = Image.open(path_input + '/' + file)
                #new_image = image.resize((512, 512))
                #new_image.save(path_output + '/' + file[:3] + '/ph1_images/' + file)
                #image.save(path_output + '/' + file[:3] + '/ph1_images/' + file,
                #           "TIFF",
                #           optimize = True,
                #           quality = 25)
                shutil.copy(path_input+'/'+file, path_output+'/'+file[:3]+'/'+'/ph1_images/'+file)

            except OSError as e:
                # If it fails, inform the user.
                print('Error: %s - %s.' % (e.filename, e.strerror))

# %%
#run wound compute code for all plate positions
for folder in os.listdir(path_output):
    input_location = Path(path_output + '/' + folder)
    try:
        print("Fighting for my life!")
        time_all, action_all = ia.run_all(input_location)
        print("tissue number:", folder, "time:", time.time())
    except Exception as ex:
        time_all.append(time.time())
        print("tissue number:", folder, "time:", time.time())
        print("---------ERROR OF SOME DESCRIPTION HAS HAPPENED-------")
        print(ex)
        print("------------------------------------------------------")
# Out:
# Fighting for my life!
# tissue number: A1 time: 1675881894.0875788
# Fighting for my life!
# tissue number: A10 time: 1675882047.0052958
# Fighting for my life!
# tissue number: A11 time: 1675882217.6291976
# Fighting for my life!
# tissue number: A12 time: 1675882402.4574316
# Fighting for my life!
# tissue number: A2 time: 1675883020.6617064
# Fighting for my life!
# tissue number: A3 time: 1675883446.1766875
# Fighting for my life!
# tissue number: A4 time: 1675883643.5808253
# Fighting for my life!
# tissue number: A5 time: 1675883853.7207685
# Fighting for my life!
# tissue number: A6 time: 1675884038.275077
# Fighting for my life!
# tissue number: A7 time: 1675884214.1088886
# Fighting for my life!
# tissue number: A8 time: 1675884405.7112248
# Fighting for my life!
# tissue number: A9 time: 1675884583.3016078
# Fighting for my life!
# tissue number: B1 time: 1675884750.4081774
# Fighting for my life!
# tissue number: B10 time: 1675884936.0680192
# Fighting for my life!
# tissue number: B11 time: 1675885449.651545
# Fighting for my life!
# tissue number: B12 time: 1675890117.8021774
# Fighting for my life!
# tissue number: B2 time: 1675890287.9032545
# Fighting for my life!
# tissue number: B3 time: 1675890497.130407
# Fighting for my life!
# tissue number: B4 time: 1675890673.0799716
# Fighting for my life!
# tissue number: B5 time: 1675890846.4635618
# Fighting for my life!
# tissue number: B6 time: 1675891016.6650689
# Fighting for my life!
# tissue number: B7 time: 1675891198.720431
# Fighting for my life!
# tissue number: B8 time: 1675891525.886866
# Fighting for my life!
# tissue number: B9 time: 1675891751.674166
# Fighting for my life!
# tissue number: C1 time: 1675891923.3818948
# Fighting for my life!
# tissue number: C10 time: 1675892343.4969485
# Fighting for my life!
# tissue number: C11 time: 1675892975.6801186
# Fighting for my life!
# tissue number: C12 time: 1675893278.9269283
# Fighting for my life!
# tissue number: C2 time: 1675893460.3891358
# Fighting for my life!
# tissue number: C3 time: 1675895037.0528514
# Fighting for my life!
# tissue number: C4 time: 1675895208.7203803
# Fighting for my life!
# tissue number: C5 time: 1675895563.3641233
# Fighting for my life!
# tissue number: C6 time: 1675895901.3510711
# Fighting for my life!
# tissue number: C7 time: 1675896068.2259498
# Fighting for my life!
# tissue number: C8 time: 1675896235.1645846
# Fighting for my life!
# tissue number: C9 time: 1675896422.490169
# Fighting for my life!
# tissue number: D1 time: 1675896595.747734
# Fighting for my life!
# tissue number: D10 time: 1675896881.9313636
# Fighting for my life!
# tissue number: D11 time: 1675897371.5101128
# Fighting for my life!
# tissue number: D12 time: 1675897716.4245076
# Fighting for my life!
# tissue number: D2 time: 1675897893.6416757
# Fighting for my life!
# tissue number: D3 time: 1675898059.080468
# Fighting for my life!
# tissue number: D4 time: 1675898232.21632
# Fighting for my life!
# tissue number: D5 time: 1675898402.7586145
# Fighting for my life!
# tissue number: D6 time: 1675898586.445027
# Fighting for my life!
# tissue number: D7 time: 1675898765.6755793
# Fighting for my life!
# tissue number: D8 time: 1675898949.1769068
# Fighting for my life!
# tissue number: D9 time: 1675899127.4110227
# Fighting for my life!
# tissue number: E1 time: 1675899303.0018017
# Fighting for my life!
# tissue number: E10 time: 1675899474.7219062
# Fighting for my life!
# tissue number: E11 time: 1675899678.242283
# Fighting for my life!
# tissue number: E12 time: 1675900052.2781959
# Fighting for my life!
# tissue number: E2 time: 1675900278.5977361
# Fighting for my life!
# tissue number: E3 time: 1675900769.141516
# Fighting for my life!
# tissue number: E4 time: 1675900953.7129142
# Fighting for my life!
# tissue number: E5 time: 1675901281.3670068
# Fighting for my life!
# tissue number: E6 time: 1675901452.027665
# Fighting for my life!
# tissue number: E7 time: 1675901647.3228288
# Fighting for my life!
# tissue number: E8 time: 1675901825.2053504
# Fighting for my life!
# tissue number: E9 time: 1675902009.0693202
# Fighting for my life!
# tissue number: F1 time: 1675902442.079899
# Fighting for my life!
# tissue number: F10 time: 1675902851.6999245
# Fighting for my life!
# tissue number: F11 time: 1675903325.4577549
# Fighting for my life!
# tissue number: F12 time: 1675903575.0043652
# Fighting for my life!
# tissue number: F2 time: 1675903744.6775758
# Fighting for my life!
# tissue number: F3 time: 1675903912.979843
# Fighting for my life!
# tissue number: F4 time: 1675904079.3620973
# Fighting for my life!
# tissue number: F5 time: 1675904247.6474102
# Fighting for my life!
# tissue number: F6 time: 1675904412.93244
# Fighting for my life!
# tissue number: F7 time: 1675904582.6534584
# Fighting for my life!
# tissue number: F8 time: 1675904754.7930477
# Fighting for my life!
# tissue number: F9 time: 1675904925.0465226
# Fighting for my life!
# tissue number: G1 time: 1675905097.3946898
# Fighting for my life!
# tissue number: G10 time: 1675906361.137074
# Fighting for my life!
# tissue number: G12 time: 1675906542.1555758
# Fighting for my life!
# tissue number: G2 time: 1675906857.1935842
# Fighting for my life!
# tissue number: G3 time: 1675907026.4731991
# Fighting for my life!
# tissue number: G4 time: 1675907196.1515346
# Fighting for my life!
# tissue number: G5 time: 1675907366.9814553
# Fighting for my life!
# tissue number: G6 time: 1675907535.0038402
# Fighting for my life!
# tissue number: G7 time: 1675907706.4877925
# Fighting for my life!
# tissue number: G8 time: 1675907944.9222994
# Fighting for my life!
# tissue number: G9 time: 1675908120.30157
# Fighting for my life!
# tissue number: H1 time: 1675908288.7436125
# Fighting for my life!
# tissue number: H10 time: 1675911605.3278904
# Fighting for my life!
# tissue number: H11 time: 1675911915.6937072
# Fighting for my life!
# tissue number: H12 time: 1675912380.155702
# Fighting for my life!
# tissue number: H2 time: 1675913211.557902
# Fighting for my life!
# tissue number: H3 time: 1675913812.414068
# Fighting for my life!
# tissue number: H4 time: 1675914120.7538807
# Fighting for my life!
# tissue number: H5 time: 1675914292.745567
# Fighting for my life!
# tissue number: H6 time: 1675914482.0089302
# Fighting for my life!
# tissue number: H7 time: 1675914697.571006
# Fighting for my life!
# tissue number: H8 time: 1675915652.7665653
# Fighting for my life!
# tissue number: H9 time: 1675915824.6372638

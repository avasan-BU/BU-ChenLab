# %%
#imports
import os, shutil, fnmatch, tkinter
from tkinter.filedialog import askdirectory
from pathlib import Path
from woundcompute import image_analysis as ia
import time

# %%
#prompt user for the file directory. Will open as a popup window named "tk"
tk_root = tkinter.Tk()
print("Please open the directory that contains your .nd file")
path_input = askdirectory(title='Select Input Folder')  # shows dialog box and return the path
print(path_input)
tk_root.destroy()
path_output = path_input + '/Sorted'

if os.path.exists(path_output):
    path_out_new = input('Enter new output folder name')
    path_output = path_input + '/' + path_out_new
    os.makedirs(path_output)
#create a new  output directory
else:
    os.makedirs(path_output)
# Out:
# Please open the directory that contains your .nd file
# D:/20230922_NHDFneo_P4_Fluor-FN-Col1/BF

# %%
#find the experiment base names based on the .nd files in the folder
basename_list = []
for file in os.listdir(path_input):
    if file.endswith('.nd'):
        name, ext = os.path.splitext(file)
        basename_list.append(name)
        #create folders for each expt
        os.makedirs(path_output + '/' + name)
print(basename_list)
# Out:
# ['tissue_ai_w1Brightfield']

# %%
type(os.listdir(path_input))
# Out:
# list

# %%
#copy files into folders grouped by expt base names
stage_pos_nd = []
for basename in basename_list:
#create folders for each expt
    os.makedirs(path_output + '/' + basename)
    #copy .nd file into respective basename folder
    shutil.copy(path_input + '/' + basename + '.nd', path_output + '/' + basename + '/' + basename + '.nd')
    with open(path_output + '/' + basename + '/' + basename + '.nd', 'r') as nd_file:
        for l_no, line in enumerate(nd_file):
            if '"NStagePositions"' in line:
                stage_pos_nd.append([int(s) for s in line.split() if s.isdigit()][-1])
                break
    #copy TIF files to respective basename folders
    for file in os.listdir(path_input):
        if file.startswith(basename + '_'):
            shutil.copy(path_input + '/' + file, path_output + '/' + basename + '/' + file)

# %%
#copy TIF files to respective basename folders
for file in os.listdir(path_input):
        if file.startswith(basename + '_') and not fnmatch.fnmatch(file, '*thumb*'):
            print(file)
# Out:
# tissue_ai_w1Brightfield_s10_t1.TIF
# tissue_ai_w1Brightfield_s10_t10.TIF
# tissue_ai_w1Brightfield_s10_t11.TIF
# tissue_ai_w1Brightfield_s10_t12.TIF
# tissue_ai_w1Brightfield_s10_t13.TIF
# tissue_ai_w1Brightfield_s10_t2.TIF
# tissue_ai_w1Brightfield_s10_t3.TIF
# tissue_ai_w1Brightfield_s10_t4.TIF
# tissue_ai_w1Brightfield_s10_t5.TIF
# tissue_ai_w1Brightfield_s10_t6.TIF
# tissue_ai_w1Brightfield_s10_t7.TIF
# tissue_ai_w1Brightfield_s10_t8.TIF
# tissue_ai_w1Brightfield_s10_t9.TIF
# tissue_ai_w1Brightfield_s11_t1.TIF
# tissue_ai_w1Brightfield_s11_t10.TIF
# tissue_ai_w1Brightfield_s11_t11.TIF
# tissue_ai_w1Brightfield_s11_t12.TIF
# tissue_ai_w1Brightfield_s11_t13.TIF
# tissue_ai_w1Brightfield_s11_t2.TIF
# tissue_ai_w1Brightfield_s11_t3.TIF
# tissue_ai_w1Brightfield_s11_t4.TIF
# tissue_ai_w1Brightfield_s11_t5.TIF
# tissue_ai_w1Brightfield_s11_t6.TIF
# tissue_ai_w1Brightfield_s11_t7.TIF
# tissue_ai_w1Brightfield_s11_t8.TIF
# tissue_ai_w1Brightfield_s11_t9.TIF
# tissue_ai_w1Brightfield_s12_t1.TIF
# tissue_ai_w1Brightfield_s12_t10.TIF
# tissue_ai_w1Brightfield_s12_t11.TIF
# tissue_ai_w1Brightfield_s12_t12.TIF
# tissue_ai_w1Brightfield_s12_t13.TIF
# tissue_ai_w1Brightfield_s12_t2.TIF
# tissue_ai_w1Brightfield_s12_t3.TIF
# tissue_ai_w1Brightfield_s12_t4.TIF
# tissue_ai_w1Brightfield_s12_t5.TIF
# tissue_ai_w1Brightfield_s12_t6.TIF
# tissue_ai_w1Brightfield_s12_t7.TIF
# tissue_ai_w1Brightfield_s12_t8.TIF
# tissue_ai_w1Brightfield_s12_t9.TIF
# tissue_ai_w1Brightfield_s13_t1.TIF
# tissue_ai_w1Brightfield_s13_t10.TIF
# tissue_ai_w1Brightfield_s13_t11.TIF
# tissue_ai_w1Brightfield_s13_t12.TIF
# tissue_ai_w1Brightfield_s13_t13.TIF
# tissue_ai_w1Brightfield_s13_t2.TIF
# tissue_ai_w1Brightfield_s13_t3.TIF
# tissue_ai_w1Brightfield_s13_t4.TIF
# tissue_ai_w1Brightfield_s13_t5.TIF
# tissue_ai_w1Brightfield_s13_t6.TIF
# tissue_ai_w1Brightfield_s13_t7.TIF
# tissue_ai_w1Brightfield_s13_t8.TIF
# tissue_ai_w1Brightfield_s13_t9.TIF
# tissue_ai_w1Brightfield_s14_t1.TIF
# tissue_ai_w1Brightfield_s14_t10.TIF
# tissue_ai_w1Brightfield_s14_t11.TIF
# tissue_ai_w1Brightfield_s14_t12.TIF
# tissue_ai_w1Brightfield_s14_t13.TIF
# tissue_ai_w1Brightfield_s14_t2.TIF
# tissue_ai_w1Brightfield_s14_t3.TIF
# tissue_ai_w1Brightfield_s14_t4.TIF
# tissue_ai_w1Brightfield_s14_t5.TIF
# tissue_ai_w1Brightfield_s14_t6.TIF
# tissue_ai_w1Brightfield_s14_t7.TIF
# tissue_ai_w1Brightfield_s14_t8.TIF
# tissue_ai_w1Brightfield_s14_t9.TIF
# tissue_ai_w1Brightfield_s15_t1.TIF
# tissue_ai_w1Brightfield_s15_t10.TIF
# tissue_ai_w1Brightfield_s15_t11.TIF
# tissue_ai_w1Brightfield_s15_t12.TIF
# tissue_ai_w1Brightfield_s15_t13.TIF
# tissue_ai_w1Brightfield_s15_t2.TIF
# tissue_ai_w1Brightfield_s15_t3.TIF
# tissue_ai_w1Brightfield_s15_t4.TIF
# tissue_ai_w1Brightfield_s15_t5.TIF
# tissue_ai_w1Brightfield_s15_t6.TIF
# tissue_ai_w1Brightfield_s15_t7.TIF
# tissue_ai_w1Brightfield_s15_t8.TIF
# tissue_ai_w1Brightfield_s15_t9.TIF
# tissue_ai_w1Brightfield_s16_t1.TIF
# tissue_ai_w1Brightfield_s16_t10.TIF
# tissue_ai_w1Brightfield_s16_t11.TIF
# tissue_ai_w1Brightfield_s16_t12.TIF
# tissue_ai_w1Brightfield_s16_t13.TIF
# tissue_ai_w1Brightfield_s16_t2.TIF
# tissue_ai_w1Brightfield_s16_t3.TIF
# tissue_ai_w1Brightfield_s16_t4.TIF
# tissue_ai_w1Brightfield_s16_t5.TIF
# tissue_ai_w1Brightfield_s16_t6.TIF
# tissue_ai_w1Brightfield_s16_t7.TIF
# tissue_ai_w1Brightfield_s16_t8.TIF
# tissue_ai_w1Brightfield_s16_t9.TIF
# tissue_ai_w1Brightfield_s17_t1.TIF
# tissue_ai_w1Brightfield_s17_t10.TIF
# tissue_ai_w1Brightfield_s17_t11.TIF
# tissue_ai_w1Brightfield_s17_t12.TIF
# tissue_ai_w1Brightfield_s17_t13.TIF
# tissue_ai_w1Brightfield_s17_t2.TIF
# tissue_ai_w1Brightfield_s17_t3.TIF
# tissue_ai_w1Brightfield_s17_t4.TIF
# tissue_ai_w1Brightfield_s17_t5.TIF
# tissue_ai_w1Brightfield_s17_t6.TIF
# tissue_ai_w1Brightfield_s17_t7.TIF
# tissue_ai_w1Brightfield_s17_t8.TIF
# tissue_ai_w1Brightfield_s17_t9.TIF
# tissue_ai_w1Brightfield_s18_t1.TIF
# tissue_ai_w1Brightfield_s18_t10.TIF
# tissue_ai_w1Brightfield_s18_t11.TIF
# tissue_ai_w1Brightfield_s18_t12.TIF
# tissue_ai_w1Brightfield_s18_t13.TIF
# tissue_ai_w1Brightfield_s18_t2.TIF
# tissue_ai_w1Brightfield_s18_t3.TIF
# tissue_ai_w1Brightfield_s18_t4.TIF
# tissue_ai_w1Brightfield_s18_t5.TIF
# tissue_ai_w1Brightfield_s18_t6.TIF
# tissue_ai_w1Brightfield_s18_t7.TIF
# tissue_ai_w1Brightfield_s18_t8.TIF
# tissue_ai_w1Brightfield_s18_t9.TIF
# tissue_ai_w1Brightfield_s19_t1.TIF
# tissue_ai_w1Brightfield_s19_t10.TIF
# tissue_ai_w1Brightfield_s19_t11.TIF
# tissue_ai_w1Brightfield_s19_t12.TIF
# tissue_ai_w1Brightfield_s19_t13.TIF
# tissue_ai_w1Brightfield_s19_t2.TIF
# tissue_ai_w1Brightfield_s19_t3.TIF
# tissue_ai_w1Brightfield_s19_t4.TIF
# tissue_ai_w1Brightfield_s19_t5.TIF
# tissue_ai_w1Brightfield_s19_t6.TIF
# tissue_ai_w1Brightfield_s19_t7.TIF
# tissue_ai_w1Brightfield_s19_t8.TIF
# tissue_ai_w1Brightfield_s19_t9.TIF
# tissue_ai_w1Brightfield_s1_t1.TIF
# tissue_ai_w1Brightfield_s1_t10.TIF
# tissue_ai_w1Brightfield_s1_t11.TIF
# tissue_ai_w1Brightfield_s1_t12.TIF
# tissue_ai_w1Brightfield_s1_t13.TIF
# tissue_ai_w1Brightfield_s1_t2.TIF
# tissue_ai_w1Brightfield_s1_t3.TIF
# tissue_ai_w1Brightfield_s1_t4.TIF
# tissue_ai_w1Brightfield_s1_t5.TIF
# tissue_ai_w1Brightfield_s1_t6.TIF
# tissue_ai_w1Brightfield_s1_t7.TIF
# tissue_ai_w1Brightfield_s1_t8.TIF
# tissue_ai_w1Brightfield_s1_t9.TIF
# tissue_ai_w1Brightfield_s20_t1.TIF
# tissue_ai_w1Brightfield_s20_t10.TIF
# tissue_ai_w1Brightfield_s20_t11.TIF
# tissue_ai_w1Brightfield_s20_t12.TIF
# tissue_ai_w1Brightfield_s20_t13.TIF
# tissue_ai_w1Brightfield_s20_t2.TIF
# tissue_ai_w1Brightfield_s20_t3.TIF
# tissue_ai_w1Brightfield_s20_t4.TIF
# tissue_ai_w1Brightfield_s20_t5.TIF
# tissue_ai_w1Brightfield_s20_t6.TIF
# tissue_ai_w1Brightfield_s20_t7.TIF
# tissue_ai_w1Brightfield_s20_t8.TIF
# tissue_ai_w1Brightfield_s20_t9.TIF
# tissue_ai_w1Brightfield_s21_t1.TIF
# tissue_ai_w1Brightfield_s21_t10.TIF
# tissue_ai_w1Brightfield_s21_t11.TIF
# tissue_ai_w1Brightfield_s21_t12.TIF
# tissue_ai_w1Brightfield_s21_t13.TIF
# tissue_ai_w1Brightfield_s21_t2.TIF
# tissue_ai_w1Brightfield_s21_t3.TIF
# tissue_ai_w1Brightfield_s21_t4.TIF
# tissue_ai_w1Brightfield_s21_t5.TIF
# tissue_ai_w1Brightfield_s21_t6.TIF
# tissue_ai_w1Brightfield_s21_t7.TIF
# tissue_ai_w1Brightfield_s21_t8.TIF
# tissue_ai_w1Brightfield_s21_t9.TIF
# tissue_ai_w1Brightfield_s22_t1.TIF
# tissue_ai_w1Brightfield_s22_t10.TIF
# tissue_ai_w1Brightfield_s22_t11.TIF
# tissue_ai_w1Brightfield_s22_t12.TIF
# tissue_ai_w1Brightfield_s22_t13.TIF
# tissue_ai_w1Brightfield_s22_t2.TIF
# tissue_ai_w1Brightfield_s22_t3.TIF
# tissue_ai_w1Brightfield_s22_t4.TIF
# tissue_ai_w1Brightfield_s22_t5.TIF
# tissue_ai_w1Brightfield_s22_t6.TIF
# tissue_ai_w1Brightfield_s22_t7.TIF
# tissue_ai_w1Brightfield_s22_t8.TIF
# tissue_ai_w1Brightfield_s22_t9.TIF
# tissue_ai_w1Brightfield_s23_t1.TIF
# tissue_ai_w1Brightfield_s23_t10.TIF
# tissue_ai_w1Brightfield_s23_t11.TIF
# tissue_ai_w1Brightfield_s23_t12.TIF
# tissue_ai_w1Brightfield_s23_t13.TIF
# tissue_ai_w1Brightfield_s23_t2.TIF
# tissue_ai_w1Brightfield_s23_t3.TIF
# tissue_ai_w1Brightfield_s23_t4.TIF
# tissue_ai_w1Brightfield_s23_t5.TIF
# tissue_ai_w1Brightfield_s23_t6.TIF
# tissue_ai_w1Brightfield_s23_t7.TIF
# tissue_ai_w1Brightfield_s23_t8.TIF
# tissue_ai_w1Brightfield_s23_t9.TIF
# tissue_ai_w1Brightfield_s24_t1.TIF
# tissue_ai_w1Brightfield_s24_t10.TIF
# tissue_ai_w1Brightfield_s24_t11.TIF
# tissue_ai_w1Brightfield_s24_t12.TIF
# tissue_ai_w1Brightfield_s24_t13.TIF
# tissue_ai_w1Brightfield_s24_t2.TIF
# tissue_ai_w1Brightfield_s24_t3.TIF
# tissue_ai_w1Brightfield_s24_t4.TIF
# tissue_ai_w1Brightfield_s24_t5.TIF
# tissue_ai_w1Brightfield_s24_t6.TIF
# tissue_ai_w1Brightfield_s24_t7.TIF
# tissue_ai_w1Brightfield_s24_t8.TIF
# tissue_ai_w1Brightfield_s24_t9.TIF
# tissue_ai_w1Brightfield_s25_t1.TIF
# tissue_ai_w1Brightfield_s25_t10.TIF
# tissue_ai_w1Brightfield_s25_t11.TIF
# tissue_ai_w1Brightfield_s25_t12.TIF
# tissue_ai_w1Brightfield_s25_t13.TIF
# tissue_ai_w1Brightfield_s25_t2.TIF
# tissue_ai_w1Brightfield_s25_t3.TIF
# tissue_ai_w1Brightfield_s25_t4.TIF
# tissue_ai_w1Brightfield_s25_t5.TIF
# tissue_ai_w1Brightfield_s25_t6.TIF
# tissue_ai_w1Brightfield_s25_t7.TIF
# tissue_ai_w1Brightfield_s25_t8.TIF
# tissue_ai_w1Brightfield_s25_t9.TIF
# tissue_ai_w1Brightfield_s26_t1.TIF
# tissue_ai_w1Brightfield_s26_t10.TIF
# tissue_ai_w1Brightfield_s26_t11.TIF
# tissue_ai_w1Brightfield_s26_t12.TIF
# tissue_ai_w1Brightfield_s26_t13.TIF
# tissue_ai_w1Brightfield_s26_t2.TIF
# tissue_ai_w1Brightfield_s26_t3.TIF
# tissue_ai_w1Brightfield_s26_t4.TIF
# tissue_ai_w1Brightfield_s26_t5.TIF
# tissue_ai_w1Brightfield_s26_t6.TIF
# tissue_ai_w1Brightfield_s26_t7.TIF
# tissue_ai_w1Brightfield_s26_t8.TIF
# tissue_ai_w1Brightfield_s26_t9.TIF
# tissue_ai_w1Brightfield_s27_t1.TIF
# tissue_ai_w1Brightfield_s27_t10.TIF
# tissue_ai_w1Brightfield_s27_t11.TIF
# tissue_ai_w1Brightfield_s27_t12.TIF
# tissue_ai_w1Brightfield_s27_t13.TIF
# tissue_ai_w1Brightfield_s27_t2.TIF
# tissue_ai_w1Brightfield_s27_t3.TIF
# tissue_ai_w1Brightfield_s27_t4.TIF
# tissue_ai_w1Brightfield_s27_t5.TIF
# tissue_ai_w1Brightfield_s27_t6.TIF
# tissue_ai_w1Brightfield_s27_t7.TIF
# tissue_ai_w1Brightfield_s27_t8.TIF
# tissue_ai_w1Brightfield_s27_t9.TIF
# tissue_ai_w1Brightfield_s28_t1.TIF
# tissue_ai_w1Brightfield_s28_t10.TIF
# tissue_ai_w1Brightfield_s28_t11.TIF
# tissue_ai_w1Brightfield_s28_t12.TIF
# tissue_ai_w1Brightfield_s28_t13.TIF
# tissue_ai_w1Brightfield_s28_t2.TIF
# tissue_ai_w1Brightfield_s28_t3.TIF
# tissue_ai_w1Brightfield_s28_t4.TIF
# tissue_ai_w1Brightfield_s28_t5.TIF
# tissue_ai_w1Brightfield_s28_t6.TIF
# tissue_ai_w1Brightfield_s28_t7.TIF
# tissue_ai_w1Brightfield_s28_t8.TIF
# tissue_ai_w1Brightfield_s28_t9.TIF
# tissue_ai_w1Brightfield_s29_t1.TIF
# tissue_ai_w1Brightfield_s29_t10.TIF
# tissue_ai_w1Brightfield_s29_t11.TIF
# tissue_ai_w1Brightfield_s29_t12.TIF
# tissue_ai_w1Brightfield_s29_t13.TIF
# tissue_ai_w1Brightfield_s29_t2.TIF
# tissue_ai_w1Brightfield_s29_t3.TIF
# tissue_ai_w1Brightfield_s29_t4.TIF
# tissue_ai_w1Brightfield_s29_t5.TIF
# tissue_ai_w1Brightfield_s29_t6.TIF
# tissue_ai_w1Brightfield_s29_t7.TIF
# tissue_ai_w1Brightfield_s29_t8.TIF
# tissue_ai_w1Brightfield_s29_t9.TIF
# tissue_ai_w1Brightfield_s2_t1.TIF
# tissue_ai_w1Brightfield_s2_t10.TIF
# tissue_ai_w1Brightfield_s2_t11.TIF
# tissue_ai_w1Brightfield_s2_t12.TIF
# tissue_ai_w1Brightfield_s2_t13.TIF
# tissue_ai_w1Brightfield_s2_t2.TIF
# tissue_ai_w1Brightfield_s2_t3.TIF
# tissue_ai_w1Brightfield_s2_t4.TIF
# tissue_ai_w1Brightfield_s2_t5.TIF
# tissue_ai_w1Brightfield_s2_t6.TIF
# tissue_ai_w1Brightfield_s2_t7.TIF
# tissue_ai_w1Brightfield_s2_t8.TIF
# tissue_ai_w1Brightfield_s2_t9.TIF
# tissue_ai_w1Brightfield_s30_t1.TIF
# tissue_ai_w1Brightfield_s30_t10.TIF
# tissue_ai_w1Brightfield_s30_t11.TIF
# tissue_ai_w1Brightfield_s30_t12.TIF
# tissue_ai_w1Brightfield_s30_t13.TIF
# tissue_ai_w1Brightfield_s30_t2.TIF
# tissue_ai_w1Brightfield_s30_t3.TIF
# tissue_ai_w1Brightfield_s30_t4.TIF
# tissue_ai_w1Brightfield_s30_t5.TIF
# tissue_ai_w1Brightfield_s30_t6.TIF
# tissue_ai_w1Brightfield_s30_t7.TIF
# tissue_ai_w1Brightfield_s30_t8.TIF
# tissue_ai_w1Brightfield_s30_t9.TIF
# tissue_ai_w1Brightfield_s31_t1.TIF
# tissue_ai_w1Brightfield_s31_t10.TIF
# tissue_ai_w1Brightfield_s31_t11.TIF
# tissue_ai_w1Brightfield_s31_t12.TIF
# tissue_ai_w1Brightfield_s31_t13.TIF
# tissue_ai_w1Brightfield_s31_t2.TIF
# tissue_ai_w1Brightfield_s31_t3.TIF
# tissue_ai_w1Brightfield_s31_t4.TIF
# tissue_ai_w1Brightfield_s31_t5.TIF
# tissue_ai_w1Brightfield_s31_t6.TIF
# tissue_ai_w1Brightfield_s31_t7.TIF
# tissue_ai_w1Brightfield_s31_t8.TIF
# tissue_ai_w1Brightfield_s31_t9.TIF
# tissue_ai_w1Brightfield_s32_t1.TIF
# tissue_ai_w1Brightfield_s32_t10.TIF
# tissue_ai_w1Brightfield_s32_t11.TIF
# tissue_ai_w1Brightfield_s32_t12.TIF
# tissue_ai_w1Brightfield_s32_t13.TIF
# tissue_ai_w1Brightfield_s32_t2.TIF
# tissue_ai_w1Brightfield_s32_t3.TIF
# tissue_ai_w1Brightfield_s32_t4.TIF
# tissue_ai_w1Brightfield_s32_t5.TIF
# tissue_ai_w1Brightfield_s32_t6.TIF
# tissue_ai_w1Brightfield_s32_t7.TIF
# tissue_ai_w1Brightfield_s32_t8.TIF
# tissue_ai_w1Brightfield_s32_t9.TIF
# tissue_ai_w1Brightfield_s33_t1.TIF
# tissue_ai_w1Brightfield_s33_t10.TIF
# tissue_ai_w1Brightfield_s33_t11.TIF
# tissue_ai_w1Brightfield_s33_t12.TIF
# tissue_ai_w1Brightfield_s33_t13.TIF
# tissue_ai_w1Brightfield_s33_t2.TIF
# tissue_ai_w1Brightfield_s33_t3.TIF
# tissue_ai_w1Brightfield_s33_t4.TIF
# tissue_ai_w1Brightfield_s33_t5.TIF
# tissue_ai_w1Brightfield_s33_t6.TIF
# tissue_ai_w1Brightfield_s33_t7.TIF
# tissue_ai_w1Brightfield_s33_t8.TIF
# tissue_ai_w1Brightfield_s33_t9.TIF
# tissue_ai_w1Brightfield_s34_t1.TIF
# tissue_ai_w1Brightfield_s34_t10.TIF
# tissue_ai_w1Brightfield_s34_t11.TIF
# tissue_ai_w1Brightfield_s34_t12.TIF
# tissue_ai_w1Brightfield_s34_t13.TIF
# tissue_ai_w1Brightfield_s34_t2.TIF
# tissue_ai_w1Brightfield_s34_t3.TIF
# tissue_ai_w1Brightfield_s34_t4.TIF
# tissue_ai_w1Brightfield_s34_t5.TIF
# tissue_ai_w1Brightfield_s34_t6.TIF
# tissue_ai_w1Brightfield_s34_t7.TIF
# tissue_ai_w1Brightfield_s34_t8.TIF
# tissue_ai_w1Brightfield_s34_t9.TIF
# tissue_ai_w1Brightfield_s35_t1.TIF
# tissue_ai_w1Brightfield_s35_t10.TIF
# tissue_ai_w1Brightfield_s35_t11.TIF
# tissue_ai_w1Brightfield_s35_t12.TIF
# tissue_ai_w1Brightfield_s35_t13.TIF
# tissue_ai_w1Brightfield_s35_t2.TIF
# tissue_ai_w1Brightfield_s35_t3.TIF
# tissue_ai_w1Brightfield_s35_t4.TIF
# tissue_ai_w1Brightfield_s35_t5.TIF
# tissue_ai_w1Brightfield_s35_t6.TIF
# tissue_ai_w1Brightfield_s35_t7.TIF
# tissue_ai_w1Brightfield_s35_t8.TIF
# tissue_ai_w1Brightfield_s35_t9.TIF
# tissue_ai_w1Brightfield_s36_t1.TIF
# tissue_ai_w1Brightfield_s36_t10.TIF
# tissue_ai_w1Brightfield_s36_t11.TIF
# tissue_ai_w1Brightfield_s36_t12.TIF
# tissue_ai_w1Brightfield_s36_t13.TIF
# tissue_ai_w1Brightfield_s36_t2.TIF
# tissue_ai_w1Brightfield_s36_t3.TIF
# tissue_ai_w1Brightfield_s36_t4.TIF
# tissue_ai_w1Brightfield_s36_t5.TIF
# tissue_ai_w1Brightfield_s36_t6.TIF
# tissue_ai_w1Brightfield_s36_t7.TIF
# tissue_ai_w1Brightfield_s36_t8.TIF
# tissue_ai_w1Brightfield_s36_t9.TIF
# tissue_ai_w1Brightfield_s37_t1.TIF
# tissue_ai_w1Brightfield_s37_t10.TIF
# tissue_ai_w1Brightfield_s37_t11.TIF
# tissue_ai_w1Brightfield_s37_t12.TIF
# tissue_ai_w1Brightfield_s37_t13.TIF
# tissue_ai_w1Brightfield_s37_t2.TIF
# tissue_ai_w1Brightfield_s37_t3.TIF
# tissue_ai_w1Brightfield_s37_t4.TIF
# tissue_ai_w1Brightfield_s37_t5.TIF
# tissue_ai_w1Brightfield_s37_t6.TIF
# tissue_ai_w1Brightfield_s37_t7.TIF
# tissue_ai_w1Brightfield_s37_t8.TIF
# tissue_ai_w1Brightfield_s37_t9.TIF
# tissue_ai_w1Brightfield_s38_t1.TIF
# tissue_ai_w1Brightfield_s38_t10.TIF
# tissue_ai_w1Brightfield_s38_t11.TIF
# tissue_ai_w1Brightfield_s38_t12.TIF
# tissue_ai_w1Brightfield_s38_t13.TIF
# tissue_ai_w1Brightfield_s38_t2.TIF
# tissue_ai_w1Brightfield_s38_t3.TIF
# tissue_ai_w1Brightfield_s38_t4.TIF
# tissue_ai_w1Brightfield_s38_t5.TIF
# tissue_ai_w1Brightfield_s38_t6.TIF
# tissue_ai_w1Brightfield_s38_t7.TIF
# tissue_ai_w1Brightfield_s38_t8.TIF
# tissue_ai_w1Brightfield_s38_t9.TIF
# tissue_ai_w1Brightfield_s39_t1.TIF
# tissue_ai_w1Brightfield_s39_t10.TIF
# tissue_ai_w1Brightfield_s39_t11.TIF
# tissue_ai_w1Brightfield_s39_t12.TIF
# tissue_ai_w1Brightfield_s39_t13.TIF
# tissue_ai_w1Brightfield_s39_t2.TIF
# tissue_ai_w1Brightfield_s39_t3.TIF
# tissue_ai_w1Brightfield_s39_t4.TIF
# tissue_ai_w1Brightfield_s39_t5.TIF
# tissue_ai_w1Brightfield_s39_t6.TIF
# tissue_ai_w1Brightfield_s39_t7.TIF
# tissue_ai_w1Brightfield_s39_t8.TIF
# tissue_ai_w1Brightfield_s39_t9.TIF
# tissue_ai_w1Brightfield_s3_t1.TIF
# tissue_ai_w1Brightfield_s3_t10.TIF
# tissue_ai_w1Brightfield_s3_t11.TIF
# tissue_ai_w1Brightfield_s3_t12.TIF
# tissue_ai_w1Brightfield_s3_t13.TIF
# tissue_ai_w1Brightfield_s3_t2.TIF
# tissue_ai_w1Brightfield_s3_t3.TIF
# tissue_ai_w1Brightfield_s3_t4.TIF
# tissue_ai_w1Brightfield_s3_t5.TIF
# tissue_ai_w1Brightfield_s3_t6.TIF
# tissue_ai_w1Brightfield_s3_t7.TIF
# tissue_ai_w1Brightfield_s3_t8.TIF
# tissue_ai_w1Brightfield_s3_t9.TIF
# tissue_ai_w1Brightfield_s40_t1.TIF
# tissue_ai_w1Brightfield_s40_t10.TIF
# tissue_ai_w1Brightfield_s40_t11.TIF
# tissue_ai_w1Brightfield_s40_t12.TIF
# tissue_ai_w1Brightfield_s40_t13.TIF
# tissue_ai_w1Brightfield_s40_t2.TIF
# tissue_ai_w1Brightfield_s40_t3.TIF
# tissue_ai_w1Brightfield_s40_t4.TIF
# tissue_ai_w1Brightfield_s40_t5.TIF
# tissue_ai_w1Brightfield_s40_t6.TIF
# tissue_ai_w1Brightfield_s40_t7.TIF
# tissue_ai_w1Brightfield_s40_t8.TIF
# tissue_ai_w1Brightfield_s40_t9.TIF
# tissue_ai_w1Brightfield_s41_t1.TIF
# tissue_ai_w1Brightfield_s41_t10.TIF
# tissue_ai_w1Brightfield_s41_t11.TIF
# tissue_ai_w1Brightfield_s41_t12.TIF
# tissue_ai_w1Brightfield_s41_t13.TIF
# tissue_ai_w1Brightfield_s41_t2.TIF
# tissue_ai_w1Brightfield_s41_t3.TIF
# tissue_ai_w1Brightfield_s41_t4.TIF
# tissue_ai_w1Brightfield_s41_t5.TIF
# tissue_ai_w1Brightfield_s41_t6.TIF
# tissue_ai_w1Brightfield_s41_t7.TIF
# tissue_ai_w1Brightfield_s41_t8.TIF
# tissue_ai_w1Brightfield_s41_t9.TIF
# tissue_ai_w1Brightfield_s42_t1.TIF
# tissue_ai_w1Brightfield_s42_t10.TIF
# tissue_ai_w1Brightfield_s42_t11.TIF
# tissue_ai_w1Brightfield_s42_t12.TIF
# tissue_ai_w1Brightfield_s42_t13.TIF
# tissue_ai_w1Brightfield_s42_t2.TIF
# tissue_ai_w1Brightfield_s42_t3.TIF
# tissue_ai_w1Brightfield_s42_t4.TIF
# tissue_ai_w1Brightfield_s42_t5.TIF
# tissue_ai_w1Brightfield_s42_t6.TIF
# tissue_ai_w1Brightfield_s42_t7.TIF
# tissue_ai_w1Brightfield_s42_t8.TIF
# tissue_ai_w1Brightfield_s42_t9.TIF
# tissue_ai_w1Brightfield_s4_t1.TIF
# tissue_ai_w1Brightfield_s4_t10.TIF
# tissue_ai_w1Brightfield_s4_t11.TIF
# tissue_ai_w1Brightfield_s4_t12.TIF
# tissue_ai_w1Brightfield_s4_t13.TIF
# tissue_ai_w1Brightfield_s4_t2.TIF
# tissue_ai_w1Brightfield_s4_t3.TIF
# tissue_ai_w1Brightfield_s4_t4.TIF
# tissue_ai_w1Brightfield_s4_t5.TIF
# tissue_ai_w1Brightfield_s4_t6.TIF
# tissue_ai_w1Brightfield_s4_t7.TIF
# tissue_ai_w1Brightfield_s4_t8.TIF
# tissue_ai_w1Brightfield_s4_t9.TIF
# tissue_ai_w1Brightfield_s5_t1.TIF
# tissue_ai_w1Brightfield_s5_t10.TIF
# tissue_ai_w1Brightfield_s5_t11.TIF
# tissue_ai_w1Brightfield_s5_t12.TIF
# tissue_ai_w1Brightfield_s5_t13.TIF
# tissue_ai_w1Brightfield_s5_t2.TIF
# tissue_ai_w1Brightfield_s5_t3.TIF
# tissue_ai_w1Brightfield_s5_t4.TIF
# tissue_ai_w1Brightfield_s5_t5.TIF
# tissue_ai_w1Brightfield_s5_t6.TIF
# tissue_ai_w1Brightfield_s5_t7.TIF
# tissue_ai_w1Brightfield_s5_t8.TIF
# tissue_ai_w1Brightfield_s5_t9.TIF
# tissue_ai_w1Brightfield_s6_t1.TIF
# tissue_ai_w1Brightfield_s6_t10.TIF
# tissue_ai_w1Brightfield_s6_t11.TIF
# tissue_ai_w1Brightfield_s6_t12.TIF
# tissue_ai_w1Brightfield_s6_t13.TIF
# tissue_ai_w1Brightfield_s6_t2.TIF
# tissue_ai_w1Brightfield_s6_t3.TIF
# tissue_ai_w1Brightfield_s6_t4.TIF
# tissue_ai_w1Brightfield_s6_t5.TIF
# tissue_ai_w1Brightfield_s6_t6.TIF
# tissue_ai_w1Brightfield_s6_t7.TIF
# tissue_ai_w1Brightfield_s6_t8.TIF
# tissue_ai_w1Brightfield_s6_t9.TIF
# tissue_ai_w1Brightfield_s7_t1.TIF
# tissue_ai_w1Brightfield_s7_t10.TIF
# tissue_ai_w1Brightfield_s7_t11.TIF
# tissue_ai_w1Brightfield_s7_t12.TIF
# tissue_ai_w1Brightfield_s7_t13.TIF
# tissue_ai_w1Brightfield_s7_t2.TIF
# tissue_ai_w1Brightfield_s7_t3.TIF
# tissue_ai_w1Brightfield_s7_t4.TIF
# tissue_ai_w1Brightfield_s7_t5.TIF
# tissue_ai_w1Brightfield_s7_t6.TIF
# tissue_ai_w1Brightfield_s7_t7.TIF
# tissue_ai_w1Brightfield_s7_t8.TIF
# tissue_ai_w1Brightfield_s7_t9.TIF
# tissue_ai_w1Brightfield_s8_t1.TIF
# tissue_ai_w1Brightfield_s8_t10.TIF
# tissue_ai_w1Brightfield_s8_t11.TIF
# tissue_ai_w1Brightfield_s8_t12.TIF
# tissue_ai_w1Brightfield_s8_t13.TIF
# tissue_ai_w1Brightfield_s8_t2.TIF
# tissue_ai_w1Brightfield_s8_t3.TIF
# tissue_ai_w1Brightfield_s8_t4.TIF
# tissue_ai_w1Brightfield_s8_t5.TIF
# tissue_ai_w1Brightfield_s8_t6.TIF
# tissue_ai_w1Brightfield_s8_t7.TIF
# tissue_ai_w1Brightfield_s8_t8.TIF
# tissue_ai_w1Brightfield_s8_t9.TIF
# tissue_ai_w1Brightfield_s9_t1.TIF
# tissue_ai_w1Brightfield_s9_t10.TIF
# tissue_ai_w1Brightfield_s9_t11.TIF
# tissue_ai_w1Brightfield_s9_t12.TIF
# tissue_ai_w1Brightfield_s9_t13.TIF
# tissue_ai_w1Brightfield_s9_t2.TIF
# tissue_ai_w1Brightfield_s9_t3.TIF
# tissue_ai_w1Brightfield_s9_t4.TIF
# tissue_ai_w1Brightfield_s9_t5.TIF
# tissue_ai_w1Brightfield_s9_t6.TIF
# tissue_ai_w1Brightfield_s9_t7.TIF
# tissue_ai_w1Brightfield_s9_t8.TIF
# tissue_ai_w1Brightfield_s9_t9.TIF

# %%
#delete thumbnail files in folder
for basename in basename_list:
    for file in os.listdir(path_output + '/' + basename):
        if fnmatch.fnmatch(file, '*thumb*'):
            # Delete the thumbnail files - with exception handling
            try:
                os.remove(path_output + '/' + basename + '/' + file)
            except OSError as e:
                # If it fails, inform the user.
                print('Error: %s - %s.' % (e.filename, e.strerror))#%%

# %%
import yaml

#Information to be stored in the yaml file
yaml_input_file = {
'version' : 1.0,
'segment_brightfield' : False,
'seg_bf_version' : 1,
'seg_bf_visualize' : False,
'segment_fluorescent' : False,
'seg_fl_version' : 1,
'seg_fl_visualize' : False,
'segment_ph1' : True,
'seg_ph1_version' : 2,
'seg_ph1_visualize' : True,
'track_brightfield' : False,
'track_bf_version' : 1,
'track_bf_visualize' : False,
'track_ph1' : False,
'track_ph1_version' : 1,
'track_ph1_visualize' : False,
'bf_seg_with_fl_seg_visualize' : False,
'bf_track_with_fl_seg_visualize' : False,
'ph1_seg_with_fl_seg_visualize' : False,
'ph1_track_with_fl_seg_visualize' : False,
}

with open(r'E:\data\store_file.yaml', 'w') as file:
    documents = yaml.dump(dict_file, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 27
#       3 #Information to be stored in the yaml file
#       4 yaml_input_file = {
#       5 'version' : 1.0,
#       6 'segment_brightfield' : False,
#    (...)
#      24 'ph1_track_with_fl_seg_visualize' : False,
#      25 }
# ---> 27 with open(r'E:\data\store_file.yaml', 'w') as file:
#      28     documents = yaml.dump(dict_file, file)
#
# File ~\Anaconda3\envs\wound-compute-env\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\data\\store_file.yaml'

# %%
#sort images into stage position folders
for index,basename in enumerate(basename_list):

    for file in os.listdir(path_output+'/'+basename):
        for stage_pos in range(1,stage_pos_nd[index]+1):

            #check if file belongs to current stage_pos group
            if fnmatch.fnmatch(file, '*s%i' % stage_pos+'_*'):

                #rename file for correct sort syntax
                file_timepoint = file.split('_t', 1)[-1].split('.', 1)[0]

                for num in range(3-len(file_timepoint)):
                    file_timepoint = '0'+file_timepoint
                filename_new = 's%i' % stage_pos+'_t'+file_timepoint+'.TIF'

                #check if stage position directory already exists and move file into this folder if it does
                if os.path.exists(path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images'):
                    try:
                        shutil.move(path_output+'/'+basename+'/'+file, path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images/'+filename_new)
                    except OSError as e:
                        # If it fails, inform the user.
                        print('Error: %s - %s.' % (e.filename, e.strerror))

                else:
                    try:
                        os.makedirs(path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images')
                        shutil.copy('G:/My Drive/Boston University/Chen Lab/Code/Anish/wc_dataset_ph1.yaml', path_output+'/'+basename+'/'+'s%i' % stage_pos+'/wc_dataset_ph1.yaml')
                        shutil.move(path_output+'/'+basename+'/'+file, path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images/'+filename_new)

                    except OSError as e:
                        # If it fails, inform the user.
                        print('Error: %s - %s.' % (e.filename, e.strerror))
            elif fnmatch.fnmatch(file, '*s%i' % stage_pos+'.TIF'):
                if os.path.exists(path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images'):
                    try:
                        shutil.move(path_output+'/'+basename+'/'+file, path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images/'+file)
                    except OSError as e:
                        # If it fails, inform the user.
                        print('Error: %s - %s.' % (e.filename, e.strerror))
                # if the directory does not already exist, create directory and move file into it
                else:
                    try:
                        os.makedirs(path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images')
                        shutil.copy('G:/My Drive/Boston University/Chen Lab/Code/Anish/wc_dataset_ph1.yaml', path_output+'/'+basename+'/'+'s%i' % stage_pos+'/wc_dataset_ph1.yaml')
                        shutil.move(path_output+'/'+basename+'/'+file, path_output+'/'+basename+'/'+'s%i' % stage_pos+'/ph1_images/'+file)

                    except OSError as e:
                        # If it fails, inform the user.
                        print('Error: %s - %s.' % (e.filename, e.strerror))

# %%
for index, basename in enumerate(basename_list):

    for stage_pos in range(1, stage_pos_nd[index]+1):
        input_location = Path(path_output+'/'+basename+'/'+'s%i' % stage_pos)
        try:
            time_all, action_all = ia.run_all(input_location)
            print("tissue number:", stage_pos, "time:", time.time())
        except Exception as ex:
            time_all.append(time.time())
            print("tissue number:", stage_pos, "time:", time.time())
            print("---------ERROR OF SOME DESCRIPTION HAS HAPPENED-------")
            print(ex)
            print("------------------------------------------------------")
# Out:
# tissue number: 1 time: 1695601018.1116521
# tissue number: 2 time: 1695601120.482176
# tissue number: 3 time: 1695601225.9117353
# tissue number: 4 time: 1695601342.7830546
# tissue number: 5 time: 1695601450.0076857
# tissue number: 6 time: 1695601526.311913
# tissue number: 7 time: 1695601668.774233
# tissue number: 8 time: 1695602238.529735
# tissue number: 9 time: 1695602313.0839746
# tissue number: 10 time: 1695602422.7549512
# tissue number: 11 time: 1695602502.0381472
# tissue number: 12 time: 1695602599.9642644
# tissue number: 13 time: 1695602792.5261235
# tissue number: 14 time: 1695602908.642871
# tissue number: 15 time: 1695602989.163265
# tissue number: 16 time: 1695603081.7520773
# tissue number: 17 time: 1695603151.0974631
# tissue number: 18 time: 1695603268.1206431
# tissue number: 19 time: 1695603353.5186136
# tissue number: 20 time: 1695603431.1218195
# tissue number: 21 time: 1695603527.1193216
# tissue number: 22 time: 1695603655.4583423
# tissue number: 23 time: 1695603755.6835568
# tissue number: 24 time: 1695603840.5750227
# tissue number: 25 time: 1695603933.151243
# tissue number: 26 time: 1695604027.011481
# tissue number: 27 time: 1695604353.15159
# tissue number: 28 time: 1695604447.1961997
# tissue number: 29 time: 1695604564.810658
# tissue number: 30 time: 1695604671.1230707
# tissue number: 31 time: 1695604800.4130068
# tissue number: 32 time: 1695604925.6773865
# tissue number: 33 time: 1695605037.7595694
# tissue number: 34 time: 1695605131.3189611
# tissue number: 35 time: 1695605243.0271988
# tissue number: 36 time: 1695605342.94433
# tissue number: 37 time: 1695605443.7243564
# tissue number: 38 time: 1695605566.2924654
# tissue number: 39 time: 1695605659.2264924
# tissue number: 40 time: 1695605752.3955138
# tissue number: 41 time: 1695605864.248466
# tissue number: 42 time: 1695605982.4061124
